# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/bsu/Downloads/round-1-island-data-bottle/prices_round_1_day_-2.csv', delimiter = ';')
df
# Out:
#        day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       -2          0  RAINFOREST_RESIN         9996             1
# 1       -2          0              KELP         1998            26
# 2       -2          0         SQUID_INK         1998            26
# 3       -2        100         SQUID_INK         1999             5
# 4       -2        100  RAINFOREST_RESIN        10000             5
# ...    ...        ...               ...          ...           ...
# 29995   -2     999800  RAINFOREST_RESIN         9996             1
# 29996   -2     999800              KELP         2026            26
# 29997   -2     999900  RAINFOREST_RESIN         9996             2
# 29998   -2     999900              KELP         2027             4
# 29999   -2     999900         SQUID_INK         2003             4
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0           9995.0          25.0          NaN           NaN        10004
# 1              NaN           NaN          NaN           NaN         2002
# 2              NaN           NaN          NaN           NaN         2002
# 3           1998.0          26.0          NaN           NaN         2001
# 4           9995.0          20.0          NaN           NaN        10005
# ...            ...           ...          ...           ...          ...
# 29995       9995.0          25.0          NaN           NaN         9998
# 29996          NaN           NaN          NaN           NaN         2028
# 29997       9995.0          30.0          NaN           NaN        10004
# 29998       2026.0          32.0          NaN           NaN         2029
# 29999       2002.0          32.0          NaN           NaN         2005
#
#        ask_volume_1  ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  \
# 0                 1      10005.0          25.0          NaN           NaN
# 1                26          NaN           NaN          NaN           NaN
# 2                26          NaN           NaN          NaN           NaN
# 3                20          NaN           NaN          NaN           NaN
# 4                20          NaN           NaN          NaN           NaN
# ...             ...          ...           ...          ...           ...
# 29995             1      10002.0           9.0      10004.0           1.0
# 29996             3       2030.0          26.0          NaN           NaN
# 29997             2      10005.0          30.0          NaN           NaN
# 29998            32          NaN           NaN          NaN           NaN
# 29999            32          NaN           NaN          NaN           NaN
#
#        mid_price  profit_and_loss
# 0        10000.0              0.0
# 1         2000.0              0.0
# 2         2000.0              0.0
# 3         2000.0              0.0
# 4        10002.5              0.0
# ...          ...              ...
# 29995     9997.0              0.0
# 29996     2027.0              0.0
# 29997    10000.0              0.0
# 29998     2028.0              0.0
# 29999     2004.0              0.0
#
# [30000 rows x 17 columns]

# %%
rainforest_resin = df[df['product'] == 'RAINFOREST_RESIN']
max_value = rainforest_resin['mid_price'].max()
min_value = rainforest_resin['mid_price'].min()
rainforest_resin
# Out:
#        day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       -2          0  RAINFOREST_RESIN         9996             1
# 4       -2        100  RAINFOREST_RESIN        10000             5
# 8       -2        200  RAINFOREST_RESIN         9996             1
# 9       -2        300  RAINFOREST_RESIN         9996             1
# 12      -2        400  RAINFOREST_RESIN         9995            20
# ...    ...        ...               ...          ...           ...
# 29985   -2     999500  RAINFOREST_RESIN         9996             2
# 29988   -2     999600  RAINFOREST_RESIN         9998             6
# 29993   -2     999700  RAINFOREST_RESIN         9995            22
# 29995   -2     999800  RAINFOREST_RESIN         9996             1
# 29997   -2     999900  RAINFOREST_RESIN         9996             2
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0           9995.0          25.0          NaN           NaN        10004
# 4           9995.0          20.0          NaN           NaN        10005
# 8           9995.0          30.0          NaN           NaN        10004
# 9           9995.0          26.0          NaN           NaN        10004
# 12             NaN           NaN          NaN           NaN         9998
# ...            ...           ...          ...           ...          ...
# 29985       9995.0          24.0          NaN           NaN        10004
# 29988       9995.0          30.0          NaN           NaN        10005
# 29993          NaN           NaN          NaN           NaN        10005
# 29995       9995.0          25.0          NaN           NaN         9998
# 29997       9995.0          30.0          NaN           NaN        10004
#
#        ask_volume_1  ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  \
# 0                 1      10005.0          25.0          NaN           NaN
# 4                20          NaN           NaN          NaN           NaN
# 8                 1      10005.0          30.0          NaN           NaN
# 9                 1      10005.0          26.0          NaN           NaN
# 12                3      10002.0           9.0      10005.0          20.0
# ...             ...          ...           ...          ...           ...
# 29985             2      10005.0          24.0          NaN           NaN
# 29988            30          NaN           NaN          NaN           NaN
# 29993            22          NaN           NaN          NaN           NaN
# 29995             1      10002.0           9.0      10004.0           1.0
# 29997             2      10005.0          30.0          NaN           NaN
#
#        mid_price  profit_and_loss
# 0        10000.0              0.0
# 4        10002.5              0.0
# 8        10000.0              0.0
# 9        10000.0              0.0
# 12        9996.5              0.0
# ...          ...              ...
# 29985    10000.0              0.0
# 29988    10001.5              0.0
# 29993    10000.0              0.0
# 29995     9997.0              0.0
# 29997    10000.0              0.0
#
# [10000 rows x 17 columns]

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

for product in df['product'].unique():
    product_df = df[df['product'] == product]
    if product == 'RAINFOREST_RESIN':
        ax1.plot(product_df['timestamp'], product_df['mid_price'], label=product, color = 'red')
    else:
        ax2.plot(product_df['timestamp'], product_df['mid_price'], label=product)

ax1.set_ylim([max_value - 20, min_value + 20])
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
